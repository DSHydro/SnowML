# %% [markdown]
# # Verify Frosty Dawgs Data Pipeline
#
# This notebook graphs results from the Frosty Dawgs data pipeline, proccessing SWE and WRF data for one region: the Skagit region. It compares the results to data compiled from similar (but not exactly the same) data in a related project (The Prior Project).  The expectation is that the two data sources should look similar but are not expected to be identical.

# %% [markdown]
# # Step 0 - Prepare the Notebook

# %%
import pandas as pd
import boto3
import s3fs
import xarray as xr
import matplotlib.pyplot as plt
import io
import requests
from io import StringIO

# %% [markdown]
# # Step 1 - Upload "Model Ready" Data Produced by Frosty Dawgs Pipeline

# %%
# def some functions to get data from S3

def s3_to_df(bucket_name, file_name):
    s3_path = f"s3://{bucket_name}/{file_name}"
    fs = s3fs.S3FileSystem(anon=False)
    with fs.open(s3_path) as f:
        ds = xr.open_dataset(f)
        ds.load()
    return ds

def s3_to_df(file_name, bucket_name):
    """
    Loads a CSV file from an S3 bucket into a pandas DataFrame.

    Parameters:
        file_name (str): The name of the CSV file in the S3 bucket.
        bucket_name (str): The name of the S3 bucket.

    Returns:
        pd.DataFrame: A pandas DataFrame containing the data from the CSV file.
    """
    s3 = boto3.client('s3')
    response = s3.get_object(Bucket=bucket_name, Key=file_name)
    content = response['Body'].read().decode('utf-8')
    df = pd.read_csv(StringIO(content))
    return df

# %%
# upload the data from S3 
bucket_name = "dawgs-model-ready"
huc_id = "17110005"  
huc_lev = "Huc10" # Huc 10 as subunit of analysis  
sub_huc = '04'
full_huc = huc_id + sub_huc
#print(full_huc)
file_name = f"model_ready_{huc_lev}_in_{huc_id}.csv"
df_dawgs = s3_to_df(file_name, bucket_name)
df_dawgs.head()
# Out:
#           day  mean_SWE      huc_id  mean_precipitation_amount  \
# 0  1996-10-01       NaN  1711000501                        NaN
# 1  1996-10-01       NaN  1711000502                        NaN
# 2  1996-10-01       NaN  1711000503                   0.000000
# 3  1996-10-01       0.0  1711000504                   0.000000
# 4  1996-10-01       0.0  1711000505                   0.368293
#
#    mean_air_temperature
# 0                   NaN
# 1                   NaN
# 2            271.722222
# 3            270.545833
# 4            270.804878

# %% [markdown]
# Note no data in 0501, 0502, 0503 as they are in Canada

# %%
# a bit of cleaning and filtering 

# Filter to the -04 subbasin 
df_dawgs_clean = df_dawgs[df_dawgs['huc_id'] == int(full_huc)]

# Ensure the 'time' column is in datetime format
df_dawgs_clean['day'] = pd.to_datetime(df_dawgs_clean['day'])

# Filter rows where 'time' is after the year 1996
df_dawgs_clean = df_dawgs_clean[df_dawgs_clean['day'] > '1996-01-01']

# Set time as the index 
df_dawgs_clean = df_dawgs_clean.set_index('day')

# Display 
df_dawgs_clean.head()

# convert units and standardize column names 
df_dawgs_clean["mean_SWE"] = df_dawgs_clean["mean_SWE"]/1000 # mm->m
df_dawgs_clean["mean_pr"] = df_dawgs_clean["mean_precipitation_amount"]/(100**2) # TO DO: EXPLAIN UNIT CHANGE
df_dawgs_clean["tair"] = df_dawgs_clean["mean_air_temperature"] - 273.15  # degrees K to degrees C
df_dawgs_clean = df_dawgs_clean[df_dawgs_clean.columns.drop(["mean_precipitation_amount", "mean_air_temperature"])]

df_dawgs_clean.head()
# Out:
# /tmp/ipykernel_12739/2600903596.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dawgs_clean['day'] = pd.to_datetime(df_dawgs_clean['day'])
#             mean_SWE      huc_id   mean_pr      tair
# day
# 1996-10-01       0.0  1711000504  0.000000 -2.604167
# 1996-10-02       0.0  1711000504  0.000085  2.695833
# 1996-10-03       0.0  1711000504  0.000244  4.516667
# 1996-10-04       0.0  1711000504  0.002057  5.812500
# 1996-10-05       0.0  1711000504  0.000039  0.950000

# %% [markdown]
# Note on units.
# frosty_dawgs initial units
#  - swe is in mm H20: see https://nsidc.org/data/nsidc-0719/versions/1#anchor-documentation
#  - precipitation_amount is in mm see https://developers.google.com/earth-engine/datasets/catalog/IDAHO_EPSCOR_GRIDMET#bands
#  - air_temperature in degrees K see id
# conversion to match Prior Project Data
# - swe from mm -> m (/1000)

# %% [markdown]
# # Step 2 - Upload Data Used from Prior Project

# %%
# mean SWE used in Prior Project collab notebook 
f = f"data_prior/wus-sr-skagit-{full_huc}-mean-swe.csv"
df_prior_swe = pd.read_csv(f)
df_prior_swe.rename(columns={'mean': 'mean_SWE'}, inplace=True)
df_prior_swe = df_prior_swe[["time", "mean_SWE"]]
df_prior_swe['time'] = pd.to_datetime(df_prior_swe['time'])
df_prior_swe = df_prior_swe[df_prior_swe['time'] >= '1995-10-01']
df_prior_swe.set_index('time', inplace=True)
print(df_prior_swe.shape)
df_prior_swe.head()
# Out:
# (9497, 1)
#             mean_SWE
# time
# 1995-10-01  0.009581
# 1995-10-02  0.009192
# 1995-10-03  0.009226
# 1995-10-04  0.009236
# 1995-10-05  0.007700

# %%
# mean Wrf used in Prior Project collab notebook 
f = f"data_prior/wrf-skagit-{full_huc}-mean.csv"
df_prior_wrf = pd.read_csv(f)

df_prior_wrf['time'] = pd.to_datetime(df_prior_wrf['time'])

# Filter rows where 'time' is after the year 1996
df_prior_wrf = df_prior_wrf[df_prior_wrf['time'] > '1996-01-01']

#set time as index
df_prior_wrf = df_prior_wrf.set_index('time')
df_prior_wrf.head()
# Out:
#                      spatial_ref          lw    precip         rh         sw  \
# time
# 1996-01-01 03:00:00            0  257.080167  0.001229  96.809417   0.000000
# 1996-01-01 06:00:00            0  256.788917  0.001229  98.915583   8.480417
# 1996-01-01 09:00:00            0  264.312917  0.001229  84.655333  95.911333
# 1996-01-01 12:00:00            0  273.713583  0.001229  70.192917  98.476750
# 1996-01-01 15:00:00            0  274.351833  0.001229  69.982833  10.405000
#
#                          tair     wind
# time
# 1996-01-01 03:00:00 -4.199000  3.53775
# 1996-01-01 06:00:00 -4.297500  3.53775
# 1996-01-01 09:00:00 -2.348500  3.53775
# 1996-01-01 12:00:00  0.030083  3.53775
# 1996-01-01 15:00:00  0.174500  3.53775

# %% [markdown]
# # Plotting

# %%
# define plotting functions

def plot_var(df1, df2, var, time_period): 
    plt.figure(figsize=(8, 4))
    plt.plot(df1.index, df1[var], label= "Prior Project", color='blue', linewidth=2)
    plt.plot(df2.index, df2[var], label ='Frosty Dawgs', color='red', linewidth=2)
    

    # Add labels and title
    plt.xlabel('Time', fontsize=12)
    plt.ylabel(var , fontsize=12)
    plt.title(f'{var} vs. Time for {time_period}', fontsize=14)

    # Improve plot appearance
    #plt.grid(visible=True, linestyle='--', alpha=0.6)
    plt.legend(fontsize=10)
    plt.tight_layout()

    # Show the plot
    plt.show()
    
def plot_var_stacked(df1, df2, var, time_period):
    # Set up the figure with two subplots (vertically stacked)
    fig, axes = plt.subplots(2, 1, figsize=(8, 8), sharex=True, sharey=True)

    # First plot (df1)
    axes[0].plot(df1.index, df1[var], label=f'{var}_prior_project', color='blue', linewidth=2)
    axes[0].set_ylabel(var, fontsize=12)
    axes[0].set_title(f"{var} vs. Time (Collab Notebook) for {time_period}", fontsize=14)
    axes[0].legend(fontsize=10)

    # Second plot (df2)
    # TO DO - FIX HARD CODE OF COL 
    axes[1].plot(df2.index, df2[var], label=f'{var} Dawgs Pipeline', color='red', linewidth=2)
    axes[1].set_xlabel('Time', fontsize=12)
    axes[1].set_ylabel(f'Mean {var}', fontsize=12)
    axes[1].set_title(f'Mean {var} vs. Time (Sues Pipeline) for {time_period}', fontsize=14)
    axes[1].legend(fontsize=10)

    # Improve plot appearance
    for ax in axes:
        ax.grid(visible=True, linestyle='--', alpha=0.6)

    # Adjust layout
    plt.tight_layout()

    # Show the plot

# %% [markdown]
# # Plot comparing Swe Datasources

# %%
time_period = "1996WY to 2024WY"
var = "mean_SWE"
plot_var(df_prior_swe, df_dawgs_clean, var, time_period)

# %%
time_period = "1996WY to 2024WY"
var = "mean_SWE"
plot_var_stacked(df_prior_swe, df_dawgs_clean, var, time_period)

# %%
# Plot Comparing Precipitation

# %%
df_prior_pr = pd.DataFrame(df_prior_wrf.resample('D')['precip'].mean())
df_prior_pr.rename(columns={'precip': 'mean_pr'}, inplace=True)
df_prior_pr.head(2)
# Out:
#              mean_pr
# time
# 1996-01-01  0.001229
# 1996-01-02  0.002645

# %%
time_period = "1996WY to 2012WY"
plot_var(df_prior_pr, df_dawgs_clean, "mean_pr", time_period)

# %%
time_period = "1996WY to 2012WY"
plot_var_stacked(df_prior_pr, df_dawgs_clean, "mean_pr", time_period)

# %% [markdown]
# # Plot AIR TEMP

# %%
df_prior_tair = pd.DataFrame(df_prior_wrf.resample('D')['tair'].mean())
df_prior_tair.head(2)
# Out:
#                 tair
# time
# 1996-01-01 -1.821881
# 1996-01-02 -1.317396

# %%
plot_var(df_prior_tair, df_dawgs_clean, "tair", time_period)
